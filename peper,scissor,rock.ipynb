# %%
import random
import sys

class gameEngine:
    
    def __init__(self):
        
        print("\t\t\t Welcome to our Game \n\n\n")
       
        game = int(input("chose your game .... [ PSR(1) , GoCar(2)] \n"))
        gameEngine.chose_game(game)
        
    
    def chose_game(game):
        while game :
            if game == 1:
                
                print("\t\t\tYou're now in game PSR\n\n")
                gameEngine.PSR()
            elif game == 2:
                gameEngine.GoCar()
                print("\t\t\tYou're now in game GoCar\n\n")
            else :
                print("\t\t\tPlease Enter right chose \n" )
                
    def PSR():
        
        print("\t\t\t\tLet's Go")
        Ai_score = 0
        player_score = 0
        chose=['peper','rock','scissor']
        Ai = random.choice(['peper','rock','scissor'])
        
        
        while player_score <= 3 and Ai_score <= 3:
            Ai = random.choice(['peper','rock','scissor'])
            player = input("enter your chose...['peper','rock','scissor']")
            if player == Ai :
                print('\t\tdraw\n')
            elif player == 'peper' and Ai == 'scissor':
                print(" \t\t Ai Win \n ")
                Ai_score += 1
            elif player == 'peper' and Ai == 'rock':
                print(" \t\t Player Win \n ")
                player_score += 1
            elif player == 'rock' and Ai == 'pepper':
                print(" \t\t AI Win \n ")
                Ai_score += 1
            elif player == 'rock' and Ai == 'scissor':
                print(" \t\t Player Win \n ")
                player_score += 1
            elif player == 'scissor' and Ai == 'rock':
                print(" \t\t Ai Win \n ")
                Ai_score += 1
            elif player == 'scissor' and Ai == 'peper':
                print(" \t\t Player Win \n ")
                player_score += 1
            else:
                print("Please Enter a valid Choise")
                
                
            if player_score == 3:
                print("\t\tGreat, YOU ARE WINNER")
                print("\t Player={0}\t\tAi={1}".format(player_score,Ai_score))
                gameEngine.play_again()
                break
            elif Ai_score == 3:
                print("\t\t OHH,AI WIN :(")
                print("\t Player={0}\t\tAi={1}".format(player_score,Ai_score))
                gameEngine.play_again()
                break
            
                
                
    def GoCar(game):
        
        Player = random.choice(['win','lose'])
        Ai = random.choce(['win','lose'])
        if player == Ai:
            print("\t\t Draw ")
        elif player== 'win' and Ai =='lose':
            print("\t\tplayer win ")
        elif player == 'lose' and Ai == 'win':
            print("\t\t  Ai win ")
    
    def play_again():
        
        exe=input("\t\tDo You Want Play Again?")
        if exe == 'yes' or exe == 'y':
            gameEngine.__init__(self)
        elif exe == 'no' or exe == 'n':
            sys.exit(1)

# %%
x= gameEngine()
# Out:
# 			 Welcome to our Game
#
#
#
# chose your game .... [ PSR(1) , GoCar(2)]
# 1
# 			You're now in game PSR
#
#
# 				Let's Go
# enter your chose...['peper','rock','scissor']peper
# 		draw
#
# enter your chose...['peper','rock','scissor']rock
# 		draw
#
# enter your chose...['peper','rock','scissor']rock
# 		draw
#
# enter your chose...['peper','rock','scissor']rock
# Please Enter a valid Choise
# enter your chose...['peper','rock','scissor']rock
# 		draw
#
# enter your chose...['peper','rock','scissor']peper
#  		 Ai Win
#
# enter your chose...['peper','rock','scissor']peper
#  		 Ai Win
#
# enter your chose...['peper','rock','scissor']peper
#  		 Ai Win
#
# 		 OHH,AI WIN :(
# 	 Player=0		Ai=3
# 		Do You Want Play Again?n
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\AHMED\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
# ...
